# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime as dt
import seaborn as sns
import streamlit as st

# %%
import pandas as pd

df = pd.read_excel(r"D:\Local disk E\Call_Center_performance\DataSets\PB-call_center.xlsx", header=None)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1003 entries, 0 to 1002
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       0 non-null      float64
#  1   1       1002 non-null   str
#  2   2       1001 non-null   str
#  3   3       999 non-null    object
#  4   4       1001 non-null   str
#  5   5       1001 non-null   object
#  6   6       995 non-null    object
#  7   7       999 non-null    object
#  8   8       0 non-null      float64
#  9   9       0 non-null      float64
#  10  10      0 non-null      float64
#  11  11      0 non-null      float64
#  12  12      0 non-null      float64
#  13  13      16 non-null     str
#  14  14      16 non-null     str
#  15  15      16 non-null     object
#  16  16      16 non-null     str
# dtypes: float64(6), object(5), str(6)
# memory usage: 151.0+ KB

# %%
df.shape
# Out:
# (1003, 17)

# %%
df.isnull().sum()
# Out:
# 0     1003
# 1        1
# 2        2
# 3        4
# 4        2
# 5        2
# 6        8
# 7        4
# 8     1003
# 9     1003
# 10    1003
# 11    1003
# 12    1003
# 13     987
# 14     987
# 15     987
# 16     987
# dtype: int64

# %%
df.head()
# Out:
#    0                 1            2         3               4   \
# 0 NaN  Call Centre Data          NaN       NaN             NaN
# 1 NaN               NaN          NaN       NaN             NaN
# 2 NaN       Call number  Customer ID  Duration  Representative
# 3 NaN         Call_7271        C0003       116             R05
# 4 NaN         Call_7272        C0004       119             R05
#
#                     5                6                    7   8   9   10  11  \
# 0                  NaN              NaN                  NaN NaN NaN NaN NaN
# 1                  NaN              NaN                  NaN NaN NaN NaN NaN
# 2         Date of Call  Purchase Amount  Satisfaction Rating NaN NaN NaN NaN
# 3  2023-01-01 00:00:00              128                  4.9 NaN NaN NaN NaN
# 4  2023-01-01 00:00:00              135                  2.9 NaN NaN NaN NaN
#
#    12           13      14   15         16
# 0 NaN          NaN     NaN  NaN        NaN
# 1 NaN          NaN     NaN  NaN        NaN
# 2 NaN  Customer ID  Gedner  Age       City
# 3 NaN        C0001    Male   41   Columbus
# 4 NaN        C0002    Male   31  Cleveland

# %%
calls = pd.read_excel(r"D:\Local disk E\Call_Center_performance\DataSets\PB-call_center.xlsx",header=2,usecols="B:H")

# %%
calls.head()
# Out:
#   Call number Customer ID  Duration Representative Date of Call  \
# 0   Call_7271       C0003     116.0            R05   2023-01-01
# 1   Call_7272       C0004     119.0            R05   2023-01-01
# 2   Call_7273       C0005      68.0            R02   2023-01-01
# 3   Call_7274       C0014     119.0            R02   2023-01-01
# 4   Call_7275       C0011     128.0            R01   2023-01-02
#
#    Purchase Amount  Satisfaction Rating
# 0            128.0                  4.9
# 1            135.0                  2.9
# 2             66.0                  4.7
# 3             22.0                  2.9
# 4             31.0                  2.8

# %%
#customer = pd.read_excel(r"E:\Call_Center_performance\DataSets\PB-call_center.xlsx",header=2,usecols="N:Q")
import pandas as pd

customer = pd.read_excel(
    r"D:\Local disk E\Call_Center_performance\DataSets\PB-call_center.xlsx",
    usecols="N:Q",
    header=2
)

print(customer.columns)
customer.head()
# Out:
# Index(['Customer ID.1', 'Gedner', 'Age', 'City'], dtype='str')
#   Customer ID.1 Gedner   Age        City
# 0         C0001   Male  41.0    Columbus
# 1         C0002   Male  31.0   Cleveland
# 2         C0003   Male  26.0  Cincinnati
# 3         C0004   Male  36.0  Cincinnati
# 4         C0005   Male  37.0    Columbus

# %%
customer.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Customer ID.1  15 non-null     str
#  1   Gedner         15 non-null     str
#  2   Age            15 non-null     float64
#  3   City           15 non-null     str
# dtypes: float64(1), str(3)
# memory usage: 32.0 KB

# %%
customer.rename(columns={"Gedner": "Gender"}, inplace=True)

# %%
print(customer.columns)
# Out:
# Index(['Customer ID.1', 'Gender', 'Age', 'City'], dtype='str')

# %%
import streamlit as st
st.title("Call Center Performance Dashboard")
# Out:
# 2026-07-07 17:30:44.468 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-07 17:30:47.249
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\Admin\AppData\Roaming\Python\Python313\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-07-07 17:30:47.250 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-07 17:30:47.251 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
customer.head()
# Out:
#   Customer ID.1 Gender   Age        City
# 0         C0001   Male  41.0    Columbus
# 1         C0002   Male  31.0   Cleveland
# 2         C0003   Male  26.0  Cincinnati
# 3         C0004   Male  36.0  Cincinnati
# 4         C0005   Male  37.0    Columbus

# %%
customer
# Out:
#     Customer ID.1 Gender   Age        City
# 0           C0001   Male  41.0    Columbus
# 1           C0002   Male  31.0   Cleveland
# 2           C0003   Male  26.0  Cincinnati
# 3           C0004   Male  36.0  Cincinnati
# 4           C0005   Male  37.0    Columbus
# ..            ...    ...   ...         ...
# 995           NaN    NaN   NaN         NaN
# 996           NaN    NaN   NaN         NaN
# 997           NaN    NaN   NaN         NaN
# 998           NaN    NaN   NaN         NaN
# 999           NaN    NaN   NaN         NaN
#
# [1000 rows x 4 columns]

# %%
calls.tail()
# Out:
#     Call number Customer ID  Duration Representative Date of Call  \
# 995   Call_8266       C0002      81.0            R05   2023-12-30
# 996   Call_8267       C0007     127.0            R04   2023-12-30
# 997   Call_8268       C0013     146.0            R05   2023-12-31
# 998   Call_8269       C0010     123.0            R05   2023-12-31
# 999   Call_8270       C0009     114.0            R01   2023-12-31
#
#      Purchase Amount  Satisfaction Rating
# 995             28.0                  3.9
# 996            215.0                  3.8
# 997            115.0                  2.3
# 998             64.0                  3.7
# 999             40.0                  3.9

# %%
customer.head()
# Out:
#   Customer ID.1 Gender   Age        City
# 0         C0001   Male  41.0    Columbus
# 1         C0002   Male  31.0   Cleveland
# 2         C0003   Male  26.0  Cincinnati
# 3         C0004   Male  36.0  Cincinnati
# 4         C0005   Male  37.0    Columbus

# %%
customer.sample(5)
# Out:
#     Customer ID.1 Gender  Age City
# 135           NaN    NaN  NaN  NaN
# 568           NaN    NaN  NaN  NaN
# 429           NaN    NaN  NaN  NaN
# 579           NaN    NaN  NaN  NaN
# 363           NaN    NaN  NaN  NaN

# %%
calls.sample(5)
# Out:
#     Call number Customer ID  Duration Representative Date of Call  \
# 747   Call_8018       C0011      96.0            R05   2023-09-23
# 884   Call_8155       C0006      41.0            R05   2023-10-29
# 244   Call_7515       C0009     140.0            R01   2023-03-19
# 539   Call_7810       C0003     141.0            R01   2023-06-11
# 60    Call_7331       C0013      74.0            R01   2023-01-24
#
#      Purchase Amount  Satisfaction Rating
# 747             80.0                  3.6
# 884            140.0                  3.7
# 244             93.0                  4.4
# 539            100.0                  4.6
# 60              66.0                  4.0

# %%
type(calls)
type(customer)
# Out:
# pandas.DataFrame

# %%
calls.shape
# Out:
# (1000, 7)

# %%
calls.columns
# Out:
# Index(['Call number', 'Customer ID', 'Duration', 'Representative',
#        'Date of Call', 'Purchase Amount', 'Satisfaction Rating'],
#       dtype='str')

# %%
calls.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Call number          1000 non-null   str
#  1   Customer ID          1000 non-null   str
#  2   Duration             998 non-null    float64
#  3   Representative       1000 non-null   str
#  4   Date of Call         1000 non-null   datetime64[us]
#  5   Purchase Amount      994 non-null    float64
#  6   Satisfaction Rating  998 non-null    float64
# dtypes: datetime64[us](1), float64(3), str(3)
# memory usage: 71.4 KB

# %%
calls.describe()
# Out:
#          Duration                Date of Call  Purchase Amount  \
# count  998.000000                        1000       994.000000
# mean    89.797595  2023-06-15 00:34:33.600000        96.504024
# min      2.000000         2023-01-01 00:00:00        20.000000
# 25%     62.000000         2023-03-20 00:00:00        50.000000
# 50%     89.000000         2023-05-25 12:00:00        88.000000
# 75%    118.750000         2023-09-24 00:00:00       130.000000
# max    176.000000         2023-12-31 00:00:00       225.000000
# std     37.617181                         NaN        52.498621
#
#        Satisfaction Rating
# count           998.000000
# mean              3.887074
# min               0.000000
# 25%               3.400000
# 50%               4.000000
# 75%               4.500000
# max               5.000000
# std               0.834874

# %%
customer.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Customer ID.1  15 non-null     str
#  1   Gender         15 non-null     str
#  2   Age            15 non-null     float64
#  3   City           15 non-null     str
# dtypes: float64(1), str(3)
# memory usage: 32.0 KB

# %%
customer.describe()
# Out:
#              Age
# count  15.000000
# mean   32.600000
# std     7.018343
# min    22.000000
# 25%    27.000000
# 50%    31.000000
# 75%    37.500000
# max    43.000000

# %%
calls.isnull().sum()
# Out:
# Call number            0
# Customer ID            0
# Duration               2
# Representative         0
# Date of Call           0
# Purchase Amount        6
# Satisfaction Rating    2
# dtype: int64

# %%
customer.isnull().sum() #SOMETHING IS ERROR NOW DOUBT
# Out:
# Customer ID.1    985
# Gender           985
# Age              985
# City             985
# dtype: int64

# %%
calls.isnull().any(axis=1)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
calls.isnull().all()
# Out:
# Call number            False
# Customer ID            False
# Duration               False
# Representative         False
# Date of Call           False
# Purchase Amount        False
# Satisfaction Rating    False
# dtype: bool

# %%
calls[calls.isnull().any(axis=1)]
# Out:
#    Call number Customer ID  Duration Representative Date of Call  \
# 10   Call_7281       C0011     102.0            R02   2023-01-03
# 16   Call_7287       C0010      99.0            R01   2023-01-05
# 38   Call_7309       C0015      81.0            R04   2023-01-17
# 47   Call_7318       C0004     104.0            R05   2023-01-19
# 48   Call_7319       C0003      90.0            R02   2023-01-20
# 50   Call_7321       C0002       NaN            R01   2023-01-20
# 54   Call_7325       C0013      59.0            R05   2023-01-22
# 55   Call_7326       C0012       NaN            R01   2023-01-22
# 57   Call_7328       C0015     118.0            R02   2023-01-23
# 61   Call_7332       C0010     130.0            R04   2023-01-24
#
#     Purchase Amount  Satisfaction Rating
# 10              NaN                  4.9
# 16              NaN                  3.9
# 38              NaN                  2.4
# 47              NaN                  4.0
# 48             64.0                  NaN
# 50             72.0                  4.3
# 54              NaN                  4.6
# 55             28.0                  4.5
# 57            126.0                  NaN
# 61              NaN                  2.5

# %%
calls["Purchase Amount"]=calls["Purchase Amount"].fillna(calls["Purchase Amount"].mean(),inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12348\1744965682.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   calls["Purchase Amount"]=calls["Purchase Amount"].fillna(calls["Purchase Amount"].mean(),inplace=True)

# %%
calls.isnull().sum()
# Out:
# Call number            0
# Customer ID            0
# Duration               2
# Representative         0
# Date of Call           0
# Purchase Amount        0
# Satisfaction Rating    2
# dtype: int64

# %%
calls["Duration"]=calls["Duration"].fillna(calls["Duration"].mean(),inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12348\2727262099.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   calls["Duration"]=calls["Duration"].fillna(calls["Duration"].mean(),inplace=True)

# %%
calls["Satisfaction Rating"]=calls["Satisfaction Rating"].fillna(calls["Satisfaction Rating"].mean(),inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12348\1235390652.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   calls["Satisfaction Rating"]=calls["Satisfaction Rating"].fillna(calls["Satisfaction Rating"].mean(),inplace=True)

# %% [markdown]
# To missing unknown

# %%
calls["Representative"]=calls["Representative"].fillna("Unknown",inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12348\538433942.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   calls["Representative"]=calls["Representative"].fillna("Unknown",inplace=True)

# %%
calls.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Call number          1000 non-null   str
#  1   Customer ID          1000 non-null   str
#  2   Duration             1000 non-null   float64
#  3   Representative       1000 non-null   str
#  4   Date of Call         1000 non-null   datetime64[us]
#  5   Purchase Amount      1000 non-null   float64
#  6   Satisfaction Rating  1000 non-null   float64
# dtypes: datetime64[us](1), float64(3), str(3)
# memory usage: 71.4 KB

# %%
calls.duplicated().sum()
# Out:
# np.int64(0)

# %%
calls.drop_duplicates().all(axis=1).sum()
# Out:
# np.int64(999)

# %%
calls[calls.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Call number, Customer ID, Duration, Representative, Date of Call, Purchase Amount, Satisfaction Rating]
# Index: []

# %%
calls.drop_duplicates(inplace=True)

# %%
calls["Date of Call"]=pd.to_datetime(calls["Date of Call"])

# %%
calls.dtypes
# Out:
# Call number                       str
# Customer ID                       str
# Duration                      float64
# Representative                    str
# Date of Call           datetime64[us]
# Purchase Amount               float64
# Satisfaction Rating           float64
# dtype: object

# %%
calls.columns
# Out:
# Index(['Call number', 'Customer ID', 'Duration', 'Representative',
#        'Date of Call', 'Purchase Amount', 'Satisfaction Rating'],
#       dtype='str')

# %% [markdown]
# Renaming Colums

# %%
calls.rename(columns={"Purchase Amount":"Purchase","Satisfaction Rating":"Rating"},inplace=True)

# %%
calls.to_csv("Cleaned_Data.csv",index=False)

# %% [markdown]
# single colum stores as series

# %%
type(calls["Customer ID"])
# Out:
# pandas.Series

# %%
calls[["Purchase","Representative","Rating"]]
# Out:
#      Purchase Representative  Rating
# 0       128.0            R05     4.9
# 1       135.0            R05     2.9
# 2        66.0            R02     4.7
# 3        22.0            R02     2.9
# 4        31.0            R01     2.8
# ..        ...            ...     ...
# 995      28.0            R05     3.9
# 996     215.0            R04     3.8
# 997     115.0            R05     2.3
# 998      64.0            R05     3.7
# 999      40.0            R01     3.9
#
# [1000 rows x 3 columns]

# %%
calls.Rating[calls.Rating<3]
# Out:
# 1      2.9
# 3      2.9
# 4      2.8
# 9      2.9
# 23     2.1
#       ...
# 979    2.1
# 980    2.8
# 983    1.7
# 993    2.9
# 997    2.3
# Name: Rating, Length: 144, dtype: float64

# %%
calls.Rating.sort_values(ascending=False)
# Out:
# 547    5.0
# 605    5.0
# 96     5.0
# 921    5.0
# 940    5.0
#       ...
# 128    1.0
# 557    0.9
# 445    0.7
# 180    0.7
# 69     0.0
# Name: Rating, Length: 1000, dtype: float64

# %%
calls.Representative.unique()
# Out:
# <ArrowStringArray>
# ['R05', 'R02', 'R01', 'R04', 'R03']
# Length: 5, dtype: str

# %%
type(customer)
# Out:
# pandas.DataFrame

# %%
customer.head()
# Out:
#   Customer ID.1 Gender   Age        City
# 0         C0001   Male  41.0    Columbus
# 1         C0002   Male  31.0   Cleveland
# 2         C0003   Male  26.0  Cincinnati
# 3         C0004   Male  36.0  Cincinnati
# 4         C0005   Male  37.0    Columbus

# %%
customer.City.unique()
# Out:
# <ArrowStringArray>
# ['Columbus', 'Cleveland', 'Cincinnati', nan]
# Length: 4, dtype: str

# %%
rep_counts=calls.Representative.value_counts()
print(rep_counts.max())
# Out:
# 218

# %%
print(calls.groupby("Representative")["Rating"].mean())
# Out:
# Representative
# R01    3.922751
# R02    3.878322
# R03    3.858937
# R04    3.897312
# R05    3.882500
# Name: Rating, dtype: float64

# %%
highest_calls=calls.groupby("Representative")["Call number"].count()
highest_calls.max()
# Out:
# np.int64(218)

# %%
merged_table=pd.merge(calls,customer,left_on="Customer ID",right_on="Customer ID.1")
print(merged_table)
# Out:
#     Call number Customer ID  Duration Representative Date of Call  Purchase  \
# 0     Call_7271       C0003     116.0            R05   2023-01-01     128.0
# 1     Call_7272       C0004     119.0            R05   2023-01-01     135.0
# 2     Call_7273       C0005      68.0            R02   2023-01-01      66.0
# 3     Call_7274       C0014     119.0            R02   2023-01-01      22.0
# 4     Call_7275       C0011     128.0            R01   2023-01-02      31.0
# ..          ...         ...       ...            ...          ...       ...
# 995   Call_8266       C0002      81.0            R05   2023-12-30      28.0
# 996   Call_8267       C0007     127.0            R04   2023-12-30     215.0
# 997   Call_8268       C0013     146.0            R05   2023-12-31     115.0
# 998   Call_8269       C0010     123.0            R05   2023-12-31      64.0
# 999   Call_8270       C0009     114.0            R01   2023-12-31      40.0
#
#      Rating Customer ID.1  Gender   Age        City
# 0       4.9         C0003    Male  26.0  Cincinnati
# 1       2.9         C0004    Male  36.0  Cincinnati
# 2       4.7         C0005    Male  37.0    Columbus
# 3       2.9         C0014  Female  38.0    Columbus
# 4       2.8         C0011  Female  30.0  Cincinnati
# ..      ...           ...     ...   ...         ...
# 995     3.9         C0002    Male  31.0   Cleveland
# 996     3.8         C0007  Female  22.0   Cleveland
# 997     2.3         C0013  Female  37.0   Cleveland
# 998     3.7         C0010  Female  30.0   Cleveland
# 999     3.9         C0009  Female  25.0    Columbus
#
# [1000 rows x 11 columns]

# %%
calls.dtypes
customer.dtypes
# Out:
# Customer ID.1        str
# Gender               str
# Age              float64
# City                 str
# dtype: object

# %%
merged_table.groupby("City")["Purchase"].sum()
# Out:
# City
# Cincinnati    26099.008048
# Cleveland     37692.016097
# Columbus      32713.000000
# Name: Purchase, dtype: float64

# %% [markdown]
# No of calls received

# %%
calls["Call number"].count()
# Out:
# np.int64(1000)

# %% [markdown]
# highest calls of representative

# %%
merged_table.groupby("Representative")["Call number"].count().sort_values(ascending=False)
# Out:
# Representative
# R02    218
# R03    207
# R05    200
# R01    189
# R04    186
# Name: Call number, dtype: int64

# %% [markdown]
# Highest purchase amt by representative

# %%
merged_table.groupby("Representative")["Purchase"].count().sort_values(ascending=False)
# Out:
# Representative
# R02    218
# R03    207
# R05    200
# R01    189
# R04    186
# Name: Purchase, dtype: int64

# %% [markdown]
# Average Statisication by repersentative

# %%
merged_table.groupby("Representative")["Rating"].mean().sort_values(ascending=False)
# Out:
# Representative
# R01    3.922751
# R04    3.897312
# R05    3.882500
# R02    3.878322
# R03    3.858937
# Name: Rating, dtype: float64

# %%
merged_table.groupby("Customer ID")['Purchase'].mean()
# Out:
# Customer ID
# C0001    104.384615
# C0002     89.428571
# C0003     96.080000
# C0004     93.896391
# C0005     98.063291
# C0006     99.612903
# C0007    107.701493
# C0008     84.898305
# C0009     95.666667
# C0010     84.916778
# C0011     91.574379
# C0012     97.414286
# C0013    104.210203
# C0014     90.066667
# C0015    110.652611
# Name: Purchase, dtype: float64

# %%
calls.describe(include="all")
# Out:
#        Call number Customer ID     Duration Representative  \
# count         1000        1000  1000.000000           1000
# unique        1000          15          NaN              5
# top      Call_7271       C0004          NaN            R02
# freq             1          82          NaN            218
# mean           NaN         NaN    89.797595            NaN
# min            NaN         NaN     2.000000            NaN
# 25%            NaN         NaN    62.000000            NaN
# 50%            NaN         NaN    89.398798            NaN
# 75%            NaN         NaN   118.250000            NaN
# max            NaN         NaN   176.000000            NaN
# std            NaN         NaN    37.579507            NaN
#
#                       Date of Call     Purchase       Rating
# count                         1000  1000.000000  1000.000000
# unique                         NaN          NaN          NaN
# top                            NaN          NaN          NaN
# freq                           NaN          NaN          NaN
# mean    2023-06-15 00:34:33.600000    96.504024     3.887074
# min            2023-01-01 00:00:00    20.000000     0.000000
# 25%            2023-03-20 00:00:00    50.000000     3.400000
# 50%            2023-05-25 12:00:00    88.000000     4.000000
# 75%            2023-09-24 00:00:00   130.000000     4.500000
# max            2023-12-31 00:00:00   225.000000     5.000000
# std                            NaN    52.340730     0.834038

# %% [markdown]
# Avg Purchase

# %%
Avg_purchase=calls["Purchase"].mean()
print(Avg_purchase)
# Out:
# 96.5040241448692

# %% [markdown]
# Average Rating

# %%
Avg_rating=calls["Rating"].mean()
print(Avg_rating)
# Out:
# 3.8870741482965934

# %% [markdown]
# Total Calls

# %%
Total_calls=calls["Call number"].count()
print(Total_calls)
# Out:
# 1000

# %% [markdown]
# Average Duration

# %%
Avg_duration=calls["Duration"].mean()
print(Avg_duration)
# Out:
# 89.79759519038076

# %% [markdown]
# Total Customers

# %%
Total_customers=calls["Customer ID"].count()
print(Total_customers)
# Out:
# 1000

# %% [markdown]
# Total Purchase Amount

# %%
Total_customers=calls["Customer ID"].count()
print(Total_customers)
# Out:
# 1000

# %%
merged_table[["Duration","Rating"]].corr()
# Out:
#           Duration    Rating
# Duration  1.000000  0.009652
# Rating    0.009652  1.000000

# %%
calls["Date of Call"].dtype
# Out:
# dtype('<M8[us]')

# %% [markdown]
# Extraction month from calls as a new colum

# %%
calls['Month']=calls['Date of Call'].dt.month_name()

# %%
calls.sample()
# Out:
#     Call number Customer ID  Duration Representative Date of Call  Purchase  \
# 905   Call_8176       C0014     110.0            R02   2023-11-10     132.0
#
#      Rating     Month
# 905     3.6  November

# %%
Monthly_calls=calls.groupby("Month")["Call number"].count().sort_values(ascending=False)
print(Monthly_calls)
# Out:
# Month
# March        155
# April        136
# October      114
# May           83
# January       79
# September     76
# June          67
# February      66
# July          64
# November      57
# December      53
# August        50
# Name: Call number, dtype: int64

# %%
Monthly_calls.plot(kind="line",marker="*")
plt.ylabel("No of calls")
plt.title("Monthly call Volume")
plt.show()

# %%
Most_call_Rep=calls.groupby("Representative")["Call number"].count()
print(Most_call_Rep)
# Out:
# Representative
# R01    189
# R02    218
# R03    207
# R04    186
# R05    200
# Name: Call number, dtype: int64

# %%
Most_call_Rep.plot(kind="bar")
plt.ylabel("No of Calls")
plt.title("Rep Call Volume")
plt.show()

# %%
Most_custo_rating=merged_table.groupby("Customer ID")["Rating"].sum()
print(Most_custo_rating)
# Out:
# Customer ID
# C0001    249.000000
# C0002    256.600000
# C0003    200.987074
# C0004    326.100000
# C0005    314.400000
# C0006    234.200000
# C0007    258.100000
# C0008    230.200000
# C0009    250.200000
# C0010    278.200000
# C0011    294.800000
# C0012    289.100000
# C0013    260.500000
# C0014    216.600000
# C0015    228.087074
# Name: Rating, dtype: float64

# %%
Most_custo_rating.plot(kind="bar")
plt.ylabel("Sum of Calls")
plt.title("Customers satisfaction Volume")
plt.show()

# %%
calls["Rating"]=calls["Rating"].round().astype(int)

# %%
calls["Rating"].value_counts().sort_index().sort_values(ascending=False).plot(kind="pie",autopct='%1.1f%%')
plt.title("Satisfaction Distribution")
# Out:
# Text(0.5, 1.0, 'Satisfaction Distribution')

# %%
Dp=calls[["Duration","Purchase"]].corr()
print(Dp)
# Out:
#           Duration  Purchase
# Duration  1.000000 -0.012585
# Purchase -0.012585  1.000000

# %%
plt.scatter(calls['Duration'],calls["Purchase"])
plt.ylabel("Purchase Amount")
plt.xlabel("Call Duration")
plt.title("Duration VS Purchase")
plt.show()

# %% [markdown]
# Extracting Number to Colum

# %%
Numeric=calls.select_dtypes(include='number')
Numeric.corr()
# Out:
#           Duration  Purchase    Rating
# Duration  1.000000 -0.012585 -0.013064
# Purchase -0.012585  1.000000 -0.008584
# Rating   -0.013064 -0.008584  1.000000

# %%
sns.heatmap(Numeric.corr(),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
merged_table=pd.merge(calls,customer,left_on="Customer ID",right_on="Customer ID.1")
print(merged_table)
# Out:
#     Call number Customer ID  Duration Representative Date of Call  Purchase  \
# 0     Call_7271       C0003     116.0            R05   2023-01-01     128.0
# 1     Call_7272       C0004     119.0            R05   2023-01-01     135.0
# 2     Call_7273       C0005      68.0            R02   2023-01-01      66.0
# 3     Call_7274       C0014     119.0            R02   2023-01-01      22.0
# 4     Call_7275       C0011     128.0            R01   2023-01-02      31.0
# ..          ...         ...       ...            ...          ...       ...
# 995   Call_8266       C0002      81.0            R05   2023-12-30      28.0
# 996   Call_8267       C0007     127.0            R04   2023-12-30     215.0
# 997   Call_8268       C0013     146.0            R05   2023-12-31     115.0
# 998   Call_8269       C0010     123.0            R05   2023-12-31      64.0
# 999   Call_8270       C0009     114.0            R01   2023-12-31      40.0
#
#      Rating     Month Customer ID.1  Gender   Age        City
# 0         5   January         C0003    Male  26.0  Cincinnati
# 1         3   January         C0004    Male  36.0  Cincinnati
# 2         5   January         C0005    Male  37.0    Columbus
# 3         3   January         C0014  Female  38.0    Columbus
# 4         3   January         C0011  Female  30.0  Cincinnati
# ..      ...       ...           ...     ...   ...         ...
# 995       4  December         C0002    Male  31.0   Cleveland
# 996       4  December         C0007  Female  22.0   Cleveland
# 997       2  December         C0013  Female  37.0   Cleveland
# 998       4  December         C0010  Female  30.0   Cleveland
# 999       4  December         C0009  Female  25.0    Columbus
#
# [1000 rows x 12 columns]

# %%
merged_table.to_csv("Cleaned_Data.csv",index=False)

# %%
! pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (1.58.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (6.2.2)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (7.1.4)
# Requirement already satisfied: click<9,>=7.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (8.4.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (3.1.50)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (2.4.0)
# Requirement already satisfied: packaging>=20 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (26.2)
# Requirement already satisfied: pandas<4,>=1.4.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (3.0.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (12.3.0)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (0.9.2)
# Requirement already satisfied: protobuf<8,>=3.20 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (5.29.6)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (24.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (2.34.2)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: starlette>=0.40.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (1.3.1)
# Requirement already satisfied: uvicorn>=0.30.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (0.49.0)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: anyio>=4.0.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (4.14.1)
# Requirement already satisfied: python-multipart>=0.0.10 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (0.0.32)
# Requirement already satisfied: websockets>=12.0.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (16.0)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (2.2.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: jinja2 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=2.4.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.23.0)
# Requirement already satisfied: colorama in c:\users\admin\appdata\roaming\python\python313\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\appdata\roaming\python\python313\site-packages (from pandas<4,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from pandas<4,>=1.4.0->streamlit) (2026.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit) (2026.6.17)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2026.6.3)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas<4,>=1.4.0->streamlit) (1.17.0)
# Requirement already satisfied: h11>=0.8 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from uvicorn>=0.30.0->streamlit) (0.16.0)
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
