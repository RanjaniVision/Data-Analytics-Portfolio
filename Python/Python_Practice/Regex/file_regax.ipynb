# %%
import re
text='python is easy'
res=re.findall('easy',text)
print(res)
# Out:
# ['easy']

# %%
import re
text='1,2,3,4,5,6,7,8,9'
data=re.findall(r'\d',text)
print(data)
# Out:
# ['1', '2', '3', '4', '5', '6', '7', '8', '9']

# %%
import re
txt='SQL Power BI'
res=re.sub('Power BI','PowerBI',txt)
print(res)
# Out:
# SQL PowerBI

# %%
import re
text='sales:500 profit:200'
res=re.findall(r'\d+',text) #\d+ means one or more digits
print(res)
# Out:
# ['500', '200']

# %%
import re
#text='john123@gmail.com'
text='web@gmail.com'
res=re.search(r'\w+',text)
print(res)
# Out:
# <re.Match object; span=(0, 3), match='web'>

# %%
import re
number='9890932311'
res=re.findall(r'\d{10}',number)
print(res)
# Out:
# ['9890932311']

# %%
#remove speacial characters 
#input=john@123
#o/p=john123
import re
gmail='john@123'
res=re.sub(r'[^a-zA-Z0-9]','',gmail)
print(res)
# Out:
# john123

# %%
#ques:2 remove extra spaces:i/p=john smith o/p=johnsmith

# %%
#Ques3: i/p='ord101 ord102 ord103' o/p=["ord101","ord102","ord103"]

# %%
#quest:4 extract email id 
# john, john@gmail.com
#sam, sam@gmail.com
#david, david@gmail.com
