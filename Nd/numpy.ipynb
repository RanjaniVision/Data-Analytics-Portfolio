# %%
import numpy as np
calls = np.array([5,7,8,9,11])
print(calls)
# Out:
# [ 5  7  8  9 11]

# %%
import numpy as np
calls=np.array([["Jan","Feb","Mar"],[300,400,500]])
print(calls)
# Out:
# [['Jan' 'Feb' 'Mar']
#  ['300' '400' '500']]

# %%
calls.shape
# Out:
# (2, 3)

# %%
import numpy as np

calls = np.array([["Jan", "Feb", "Mar"],
                  [20,30,50],
                  [60,80,90],
                  [10,5,2]])

print(calls[2,1]) 
print(calls[1:,2])
print(calls[0])
calls[2,2]
calls[2,1]
print(calls[1,2])
print(calls[0,1])

# %%
import numpy as np
no=np.array([3.8,6,4,2,3,1])
no[(no>=2) & (no<=4)]
print(no)

# %%
import numpy as np
no=np.array([3.8,6,4,2,3,1])
#np.sum(no)
#np.min(no)
#np.max(no)
np.std(no)

# %%
import numpy as np

calls = np.array([["Jan", "Feb", "Mar"],
                  [20,30,50],
                  [60,80,90],
                  [10,5,2]])
#np.sum(calls[1:].astype(int))
#np.mean(calls[1:].astype(int))
np.std(calls[1:].astype(int))

# %%
North=np.array([5,100,20])
South=np.array([3,2,5])
np.concatenate([North,South])
print(np.concatenate([North,South]))

# %%
North=np.array([5,100,20])
South=np.array([3,2,5])
np.add(North,South)
print(np.add(North,South))

# %%
calls = np.array([["Jan", "Feb", "Mar"],
                  [20,30,50],
                  [60,80,90],
                  [10,5,2]])
np.sum(calls[1:].astype(int))
