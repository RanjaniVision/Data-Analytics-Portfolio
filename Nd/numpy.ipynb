# %%
import numpy as np
calls = np.array([5,7,8,9,11])
print(calls)
# Out:
# [ 5  7  8  9 11]

# %%
import numpy as np
calls=np.array([["Jan","Feb","Mar"],[300,400,500]])
print(calls)
# Out:
# [['Jan' 'Feb' 'Mar']
#  ['300' '400' '500']]

# %%
calls.shape
# Out:
# (2, 3)
