# %%
try:
    age=int(input("enter the age"))
    print(age)
except:
    print('Invalid Age')
# Out:
# Invalid Age

# %%
try:
    o=file=open('sales.csv','r')
except:
    print('File not found')
finally:
    if 'o' in locals():
        o.close()
